# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import joblib

# Load iris dataset (pastikan file iris.csv ADA di folder notebook)
iris = pd.read_csv("iris.csv")

X = iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y = iris['Species']

# Label encode species
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.3, random_state=42, stratify=y_encoded
)

# Train KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
joblib.dump(knn, "knn_model.sav")
joblib.dump(le, "label_encoder.sav")

print("knn_model.sav & label_encoder.sav created!")
# Out:
# knn_model.sav & label_encoder.sav created!
